# %%
import numpy as np
from qcdenoise import circuit_sampling_utils
import os, json
os.environ["OMP_NUM_THREADS"]='1'

# %% [markdown]
# #### Set Parameters

# %%
file_name = 'run_test'
n_samples = 100
n_parts = 1
n_procs = 38 # number of processors to use
circuit_name = 'GHZ'
n_qubits = 8
# 10-qubit GHZ with randomly inserted unitary operators and noised'em up
noise_specs = {'class':'unitary_noise', 
                # 'type':'phase_amplitude_damping_error', 
                'type':'amplitude_damping_error', 
                'max_prob': 0.4, 
                'unitary_op':None}

# %% [markdown]
# #### Sample Circuit

# %%
# run it
for i in range(n_parts):
    all_results = circuit_sampling_utils.parallel_sampler(n_samples, n_qubits, circuit_name, noise_specs)
    np.save('%s_%d.npy'%(file_name, i), all_results, allow_pickle=False)
# Out:
# PID: 10127, Sample #: 0
# PID: 10126, Sample #: 0
# PID: 10128, Sample #: 0
# PID: 10134, Sample #: 0
# PID: 10137, Sample #: 0
# PID: 10138, Sample #: 0
# PID: 10139, Sample #: 0
# PID: 10135, Sample #: 0
# PID: 10133, Sample #: 0
# PID: 10141, Sample #: 0
# PID: 10136, Sample #: 0
# PID: 10142, Sample #: 0
# PID: 10144, Sample #: 0
# PID: 10145, Sample #: 0
# PID: 10146, Sample #: 0
# PID: 10147, Sample #: 0
# PID: 10148, Sample #: 0
# PID: 10149, Sample #: 0
# PID: 10143, Sample #: 0
# PID: 10151, Sample #: 0
# PID: 10152, Sample #: 0
# PID: 10153, Sample #: 0
# PID: 10140, Sample #: 0
# PID: 10156, Sample #: 0
# PID: 10158, Sample #: 0
# PID: 10159, Sample #: 0
# PID: 10154, Sample #: 0
# PID: 10150, Sample #: 0
# PID: 10157, Sample #: 0
# PID: 10160, Sample #: 0
# PID: 10161, Sample #: 0
# PID: 10165, Sample #: 0
# PID: 10164, Sample #: 0
# PID: 10155, Sample #: 0
# PID: 10163, Sample #: 0
# PID: 10162, Sample #: 0
# PID: 10130, Sample #: 0
# PID: 10132, Sample #: 0
# PID: 10129, Sample #: 0
# PID: 10131, Sample #: 0
# PID: 10153, Sample #: 10
# PID: 10131, Sample #: 10
# PID: 10127, Sample #: 10
# PID: 10162, Sample #: 10
# PID: 10161, Sample #: 10
# PID: 10148, Sample #: 10
# PID: 10159, Sample #: 10
# PID: 10164, Sample #: 10
# PID: 10157, Sample #: 10
# PID: 10137, Sample #: 10
# PID: 10150, Sample #: 10
# PID: 10144, Sample #: 10
# PID: 10156, Sample #: 10
# PID: 10151, Sample #: 10
# PID: 10145, Sample #: 10
# PID: 10146, Sample #: 10
# PID: 10133, Sample #: 10
# PID: 10149, Sample #: 10
# PID: 10143, Sample #: 10
# PID: 10163, Sample #: 10
# PID: 10126, Sample #: 10
# PID: 10154, Sample #: 10
# PID: 10160, Sample #: 10
# PID: 10152, Sample #: 10
# PID: 10135, Sample #: 10
# PID: 10139, Sample #: 10
# PID: 10128, Sample #: 10
# PID: 10142, Sample #: 10
# PID: 10130, Sample #: 10
# PID: 10141, Sample #: 10
# PID: 10165, Sample #: 10
# PID: 10134, Sample #: 10
# PID: 10140, Sample #: 10
# PID: 10155, Sample #: 10
# PID: 10129, Sample #: 10
# PID: 10132, Sample #: 10
# PID: 10136, Sample #: 10
# PID: 10138, Sample #: 10
# PID: 10158, Sample #: 10
# PID: 10147, Sample #: 10
# PID: 10162, Sample #: 20
# PID: 10131, Sample #: 20
# PID: 10127, Sample #: 20
# PID: 10148, Sample #: 20
# PID: 10153, Sample #: 20
# PID: 10151, Sample #: 20
# PID: 10146, Sample #: 20
# PID: 10133, Sample #: 20
# PID: 10149, Sample #: 20
# PID: 10143, Sample #: 20
# PID: 10161, Sample #: 20
# PID: 10144, Sample #: 20
# PID: 10137, Sample #: 20
# PID: 10164, Sample #: 20
# PID: 10157, Sample #: 20
# PID: 10156, Sample #: 20
# PID: 10145, Sample #: 20
# PID: 10159, Sample #: 20
# PID: 10126, Sample #: 20
# PID: 10163, Sample #: 20
# PID: 10154, Sample #: 20
# PID: 10150, Sample #: 20
# PID: 10128, Sample #: 20
# PID: 10160, Sample #: 20
# PID: 10134, Sample #: 20
# PID: 10139, Sample #: 20
# PID: 10129, Sample #: 20
# PID: 10152, Sample #: 20
# PID: 10135, Sample #: 20
# PID: 10138, Sample #: 20
# PID: 10165, Sample #: 20
# PID: 10132, Sample #: 20
# PID: 10155, Sample #: 20
# PID: 10141, Sample #: 20
# PID: 10140, Sample #: 20
# PID: 10130, Sample #: 20
# PID: 10142, Sample #: 20
# PID: 10147, Sample #: 20
# PID: 10136, Sample #: 20
# PID: 10158, Sample #: 20
# PID: 10162, Sample #: 30
# PID: 10148, Sample #: 30
# PID: 10164, Sample #: 30
# PID: 10133, Sample #: 30
# PID: 10149, Sample #: 30
# PID: 10127, Sample #: 30
# PID: 10146, Sample #: 30
# PID: 10126, Sample #: 30
# PID: 10131, Sample #: 30
# PID: 10151, Sample #: 30
# PID: 10137, Sample #: 30
# PID: 10145, Sample #: 30
# PID: 10152, Sample #: 30
# PID: 10159, Sample #: 30
# PID: 10154, Sample #: 30
# PID: 10129, Sample #: 30
# PID: 10143, Sample #: 30
# PID: 10150, Sample #: 30
# PID: 10163, Sample #: 30
# PID: 10156, Sample #: 30
# PID: 10128, Sample #: 30
# PID: 10130, Sample #: 30
# PID: 10160, Sample #: 30
# PID: 10144, Sample #: 30
# PID: 10161, Sample #: 30
# PID: 10165, Sample #: 30
# PID: 10155, Sample #: 30
# PID: 10141, Sample #: 30
# PID: 10140, Sample #: 30
# PID: 10134, Sample #: 30
# PID: 10157, Sample #: 30
# PID: 10135, Sample #: 30
# PID: 10142, Sample #: 30
# PID: 10153, Sample #: 30
# PID: 10147, Sample #: 30
# PID: 10132, Sample #: 30
# PID: 10139, Sample #: 30
# PID: 10136, Sample #: 30
# PID: 10158, Sample #: 30
# PID: 10138, Sample #: 30
# PID: 10127, Sample #: 40
# PID: 10164, Sample #: 40
# PID: 10148, Sample #: 40
# PID: 10131, Sample #: 40
# PID: 10133, Sample #: 40
# PID: 10146, Sample #: 40
# PID: 10152, Sample #: 40
# PID: 10149, Sample #: 40
# PID: 10156, Sample #: 40
# PID: 10162, Sample #: 40
# PID: 10137, Sample #: 40
# PID: 10145, Sample #: 40
# PID: 10143, Sample #: 40
# PID: 10150, Sample #: 40
# PID: 10130, Sample #: 40
# PID: 10126, Sample #: 40
# PID: 10163, Sample #: 40
# PID: 10155, Sample #: 40
# PID: 10165, Sample #: 40
# PID: 10151, Sample #: 40
# PID: 10159, Sample #: 40
# PID: 10141, Sample #: 40
# PID: 10128, Sample #: 40
# PID: 10129, Sample #: 40
# PID: 10134, Sample #: 40
# PID: 10153, Sample #: 40
# PID: 10140, Sample #: 40
# PID: 10161, Sample #: 40
# PID: 10142, Sample #: 40
# PID: 10132, Sample #: 40
# PID: 10135, Sample #: 40
# PID: 10157, Sample #: 40
# PID: 10136, Sample #: 40
# PID: 10147, Sample #: 40
# PID: 10154, Sample #: 40
# PID: 10160, Sample #: 40
# PID: 10139, Sample #: 40
# PID: 10158, Sample #: 40
# PID: 10138, Sample #: 40
# PID: 10144, Sample #: 40
# PID: 10127, Sample #: 50
# PID: 10133, Sample #: 50
# PID: 10164, Sample #: 50
# PID: 10156, Sample #: 50
# PID: 10148, Sample #: 50
# PID: 10162, Sample #: 50
# PID: 10152, Sample #: 50
# PID: 10131, Sample #: 50
# PID: 10146, Sample #: 50
# PID: 10149, Sample #: 50
# PID: 10137, Sample #: 50
# PID: 10130, Sample #: 50
# PID: 10143, Sample #: 50
# PID: 10159, Sample #: 50
# PID: 10134, Sample #: 50
# PID: 10163, Sample #: 50
# PID: 10126, Sample #: 50
# PID: 10150, Sample #: 50
# PID: 10155, Sample #: 50
# PID: 10151, Sample #: 50
# PID: 10165, Sample #: 50
# PID: 10128, Sample #: 50
# PID: 10141, Sample #: 50
# PID: 10129, Sample #: 50
# PID: 10145, Sample #: 50
# PID: 10140, Sample #: 50
# PID: 10153, Sample #: 50
# PID: 10135, Sample #: 50
# PID: 10154, Sample #: 50
# PID: 10132, Sample #: 50
# PID: 10147, Sample #: 50
# PID: 10160, Sample #: 50
# PID: 10139, Sample #: 50
# PID: 10136, Sample #: 50
# PID: 10142, Sample #: 50
# PID: 10144, Sample #: 50
# PID: 10161, Sample #: 50
# PID: 10138, Sample #: 50
# PID: 10158, Sample #: 50
# PID: 10157, Sample #: 50
# PID: 10156, Sample #: 60
# PID: 10133, Sample #: 60
# PID: 10164, Sample #: 60
# PID: 10146, Sample #: 60
# PID: 10149, Sample #: 60
# PID: 10127, Sample #: 60
# PID: 10143, Sample #: 60
# PID: 10148, Sample #: 60
# PID: 10152, Sample #: 60
# PID: 10162, Sample #: 60
# PID: 10131, Sample #: 60
# PID: 10159, Sample #: 60
# PID: 10130, Sample #: 60
# PID: 10137, Sample #: 60
# PID: 10134, Sample #: 60
# PID: 10128, Sample #: 60
# PID: 10150, Sample #: 60
# PID: 10155, Sample #: 60
# PID: 10165, Sample #: 60
# PID: 10163, Sample #: 60
# PID: 10141, Sample #: 60
# PID: 10151, Sample #: 60
# PID: 10147, Sample #: 60
# PID: 10132, Sample #: 60
# PID: 10136, Sample #: 60
# PID: 10126, Sample #: 60
# PID: 10154, Sample #: 60
# PID: 10140, Sample #: 60
# PID: 10135, Sample #: 60
# PID: 10129, Sample #: 60
# PID: 10144, Sample #: 60
# PID: 10160, Sample #: 60
# PID: 10138, Sample #: 60
# PID: 10153, Sample #: 60
# PID: 10139, Sample #: 60
# PID: 10161, Sample #: 60
# PID: 10142, Sample #: 60
# PID: 10145, Sample #: 60
# PID: 10158, Sample #: 60
# PID: 10157, Sample #: 60
# PID: 10149, Sample #: 70
# PID: 10156, Sample #: 70
# PID: 10152, Sample #: 70
# PID: 10133, Sample #: 70
# PID: 10146, Sample #: 70
# PID: 10162, Sample #: 70
# PID: 10143, Sample #: 70
# PID: 10163, Sample #: 70
# PID: 10130, Sample #: 70
# PID: 10127, Sample #: 70
# PID: 10164, Sample #: 70
# PID: 10148, Sample #: 70
# PID: 10128, Sample #: 70
# PID: 10151, Sample #: 70
# PID: 10159, Sample #: 70
# PID: 10137, Sample #: 70
# PID: 10134, Sample #: 70
# PID: 10160, Sample #: 70
# PID: 10155, Sample #: 70
# PID: 10165, Sample #: 70
# PID: 10141, Sample #: 70
# PID: 10131, Sample #: 70
# PID: 10136, Sample #: 70
# PID: 10132, Sample #: 70
# PID: 10126, Sample #: 70
# PID: 10150, Sample #: 70
# PID: 10129, Sample #: 70
# PID: 10147, Sample #: 70
# PID: 10154, Sample #: 70
# PID: 10138, Sample #: 70
# PID: 10140, Sample #: 70
# PID: 10139, Sample #: 70
# PID: 10144, Sample #: 70
# PID: 10135, Sample #: 70
# PID: 10161, Sample #: 70
# PID: 10153, Sample #: 70
# PID: 10157, Sample #: 70
# PID: 10158, Sample #: 70
# PID: 10142, Sample #: 70
# PID: 10145, Sample #: 70
# PID: 10133, Sample #: 80
# PID: 10164, Sample #: 80
# PID: 10146, Sample #: 80
# PID: 10152, Sample #: 80
# PID: 10163, Sample #: 80
# PID: 10127, Sample #: 80
# PID: 10147, Sample #: 80
# PID: 10149, Sample #: 80
# PID: 10162, Sample #: 80
# PID: 10155, Sample #: 80
# PID: 10148, Sample #: 80
# PID: 10159, Sample #: 80
# PID: 10165, Sample #: 80
# PID: 10128, Sample #: 80
# PID: 10151, Sample #: 80
# PID: 10132, Sample #: 80
# PID: 10131, Sample #: 80
# PID: 10143, Sample #: 80
# PID: 10156, Sample #: 80
# PID: 10139, Sample #: 80
# PID: 10130, Sample #: 80
# PID: 10140, Sample #: 80
# PID: 10137, Sample #: 80
# PID: 10134, Sample #: 80
# PID: 10154, Sample #: 80
# PID: 10126, Sample #: 80
# PID: 10136, Sample #: 80
# PID: 10129, Sample #: 80
# PID: 10150, Sample #: 80
# PID: 10144, Sample #: 80
# PID: 10138, Sample #: 80
# PID: 10141, Sample #: 80
# PID: 10153, Sample #: 80
# PID: 10160, Sample #: 80
# PID: 10161, Sample #: 80
# PID: 10145, Sample #: 80
# PID: 10135, Sample #: 80
# PID: 10158, Sample #: 80
# PID: 10157, Sample #: 80
# PID: 10142, Sample #: 80
# PID: 10164, Sample #: 90
# PID: 10133, Sample #: 90
# PID: 10148, Sample #: 90
# PID: 10147, Sample #: 90
# PID: 10132, Sample #: 90
# PID: 10152, Sample #: 90
# PID: 10149, Sample #: 90
# PID: 10156, Sample #: 90
# PID: 10151, Sample #: 90
# PID: 10130, Sample #: 90
# PID: 10155, Sample #: 90
# PID: 10162, Sample #: 90
# PID: 10140, Sample #: 90
# PID: 10139, Sample #: 90
# PID: 10128, Sample #: 90
# PID: 10127, Sample #: 90
# PID: 10146, Sample #: 90
# PID: 10165, Sample #: 90
# PID: 10143, Sample #: 90
# PID: 10134, Sample #: 90
# PID: 10131, Sample #: 90
# PID: 10163, Sample #: 90
# PID: 10154, Sample #: 90
# PID: 10159, Sample #: 90
# PID: 10136, Sample #: 90
# PID: 10137, Sample #: 90
# PID: 10138, Sample #: 90
# PID: 10144, Sample #: 90
# PID: 10141, Sample #: 90
# PID: 10129, Sample #: 90
# PID: 10160, Sample #: 90
# PID: 10150, Sample #: 90
# PID: 10161, Sample #: 90
# PID: 10126, Sample #: 90
# PID: 10145, Sample #: 90
# PID: 10158, Sample #: 90
# PID: 10135, Sample #: 90
# PID: 10153, Sample #: 90
# PID: 10157, Sample #: 90
# PID: 10142, Sample #: 90

# %% [markdown]
# #### Save params in json

# %%
# dump data generation run into json
noise_specs['circuit_name'] = circuit_name
noise_specs['n_qubits'] = n_qubits
noise_specs['n_samples'] = n_samples * n_procs * n_parts
with open('%s.json'%file_name, mode='w') as fp:
    json.dump(noise_specs, fp, indent=0)
